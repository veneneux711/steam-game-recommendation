# %%
import pandas as pd
reviews = pd.read_csv("recommendations.csv")
games = pd.read_csv("games.csv")

# %%
print(reviews)
# Out:
#            app_id  helpful  funny        date  is_recommended  hours  \
# 0          975370        0      0  2022-12-12            True   36.3
# 1          304390        4      0  2017-02-17           False   11.5
# 2         1085660        2      0  2019-11-17            True  336.5
# 3          703080        0      0  2022-09-23            True   27.4
# 4          526870        0      0  2021-01-10            True    7.9
# ...           ...      ...    ...         ...             ...    ...
# 41154789   633230        0      0  2021-02-15            True   41.0
# 41154790   758870        8      0  2019-07-18           False    8.0
# 41154791   696170        3     10  2018-03-26           False    2.0
# 41154792   696170        0      0  2018-06-11            True    4.0
# 41154793  1089980        2      0  2020-09-16            True   14.0
#
#            user_id  review_id
# 0            51580          0
# 1             2586          1
# 2           253880          2
# 3           259432          3
# 4            23869          4
# ...            ...        ...
# 41154789   1606890   41154789
# 41154790   1786254   41154790
# 41154791   6370324   41154791
# 41154792   1044289   41154792
# 41154793  13971935   41154793
#
# [41154794 rows x 8 columns]

# %%
reviews = reviews.drop(columns= ['helpful', 'funny', 'date', 'hours', 'review_id'])
print(reviews)
# Out:
#            app_id  is_recommended   user_id
# 0          975370            True     51580
# 1          304390           False      2586
# 2         1085660            True    253880
# 3          703080            True    259432
# 4          526870            True     23869
# ...           ...             ...       ...
# 41154789   633230            True   1606890
# 41154790   758870           False   1786254
# 41154791   696170           False   6370324
# 41154792   696170            True   1044289
# 41154793  1089980            True  13971935
#
# [41154794 rows x 3 columns]

# %%
print(games)
# Out:
#         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
#          mac  linux           rating  positive_ratio  user_reviews  \
# 0      False  False    Very Positive              84          2199
# 1      False  False         Positive              85            21
# 2       True   True    Very Positive              92          3722
# 3      False  False            Mixed              61           873
# 4       True  False    Very Positive              88          8784
# ...      ...    ...              ...             ...           ...
# 50867  False  False    Very Positive              96           101
# 50868  False  False  Mostly Negative              38         29458
# 50869  False  False    Very Positive              89          1128
# 50870  False  False    Very Positive              95            82
# 50871  False  False    Very Positive              88           144
#
#        price_final  price_original  discount  steam_deck
# 0             9.99            9.99       0.0        True
# 1             2.99            2.99       0.0        True
# 2            14.99           14.99       0.0        True
# 3            14.99           14.99       0.0        True
# 4            11.99           11.99       0.0        True
# ...            ...             ...       ...         ...
# 50867        22.00            0.00       0.0        True
# 50868        40.00            0.00       0.0        True
# 50869        30.00            0.00       0.0        True
# 50870        17.00            0.00       0.0        True
# 50871         4.00            0.00       0.0        True
#
# [50872 rows x 13 columns]

# %%
games = games[games['win']]
print(games)
# Out:
#         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
#          mac  linux           rating  positive_ratio  user_reviews  \
# 0      False  False    Very Positive              84          2199
# 1      False  False         Positive              85            21
# 2       True   True    Very Positive              92          3722
# 3      False  False            Mixed              61           873
# 4       True  False    Very Positive              88          8784
# ...      ...    ...              ...             ...           ...
# 50867  False  False    Very Positive              96           101
# 50868  False  False  Mostly Negative              38         29458
# 50869  False  False    Very Positive              89          1128
# 50870  False  False    Very Positive              95            82
# 50871  False  False    Very Positive              88           144
#
#        price_final  price_original  discount  steam_deck
# 0             9.99            9.99       0.0        True
# 1             2.99            2.99       0.0        True
# 2            14.99           14.99       0.0        True
# 3            14.99           14.99       0.0        True
# 4            11.99           11.99       0.0        True
# ...            ...             ...       ...         ...
# 50867        22.00            0.00       0.0        True
# 50868        40.00            0.00       0.0        True
# 50869        30.00            0.00       0.0        True
# 50870        17.00            0.00       0.0        True
# 50871         4.00            0.00       0.0        True
#
# [50076 rows x 13 columns]

# %%
games = games.drop(columns= ['win', 'mac', 'linux', 'rating', 'price_final', 'price_original', 'discount', 'steam_deck'])
print(games)
# Out:
#         app_id                                      title date_release  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21
# 1        22364                    BRINK: Agents of Change   2011-08-03
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24
# 3       226560                         Escape Dead Island   2014-11-18
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27
# ...        ...                                        ...          ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28
# 50868  1272080                                   PAYDAY 3   2023-09-21
# 50869  1402110                                 Eternights   2023-09-11
# 50870  2272250                        Forgive Me Father 2   2023-10-19
# 50871  2488510                                  FatalZone   2023-10-23
#
#        positive_ratio  user_reviews
# 0                  84          2199
# 1                  85            21
# 2                  92          3722
# 3                  61           873
# 4                  88          8784
# ...               ...           ...
# 50867              96           101
# 50868              38         29458
# 50869              89          1128
# 50870              95            82
# 50871              88           144
#
# [50076 rows x 5 columns]

# %%
games['sort_value'] = (games['positive_ratio']/100) ** 10 * games['user_reviews']

# Sort DataFrame based on sort_value in descending order
games = games.sort_values(by='sort_value', ascending=False)
print(games)
# Out:
#         app_id                                title date_release  \
# 14398      730     Counter-Strike: Global Offensive   2012-08-21
# 13035   105600                             Terraria   2011-05-16
# 15363     4000                          Garry's Mod   2006-11-29
# 47791   431960                     Wallpaper Engine   2018-11-01
# 47380      440                      Team Fortress 2   2007-10-10
# ...        ...                                  ...          ...
# 41343  2167800                   Idle Cyber Dungeon   2022-10-13
# 35322  1686500  Discord Bot Workshop [EARLY ACCESS]   2021-09-22
# 21469   978610           ★Fallalypse ★ Disconnect ❄   2019-05-24
# 24794  1173340                           War Trains   2019-10-22
# 43188  1007970        This Side (Early Access Game)   2019-05-15
#
#        positive_ratio  user_reviews    sort_value
# 14398              88       7494460  2.087214e+06
# 13035              97        943413  6.956955e+05
# 15363              96        853733  5.675896e+05
# 47791              98        637341  5.207540e+05
# 47380              93        985819  4.771190e+05
# ...               ...           ...           ...
# 41343               0            11  0.000000e+00
# 35322               0            10  0.000000e+00
# 21469               0            10  0.000000e+00
# 24794               0            11  0.000000e+00
# 43188               0            10  0.000000e+00
#
# [50076 rows x 6 columns]

# %%
games = games[games["user_reviews"] >= 100]
games.insert(0, 'sort_rank', range(1, len(games) + 1))
print(games)
# Out:
#        sort_rank   app_id                                 title date_release  \
# 14398          1      730      Counter-Strike: Global Offensive   2012-08-21
# 13035          2   105600                              Terraria   2011-05-16
# 15363          3     4000                           Garry's Mod   2006-11-29
# 47791          4   431960                      Wallpaper Engine   2018-11-01
# 47380          5      440                       Team Fortress 2   2007-10-10
# ...          ...      ...                                   ...          ...
# 14292      18175  2338770                              NBA 2K24   2023-09-07
# 37568      18176   913780                              NEW LIFE   2019-08-12
# 43990      18177  1621031  Tiny Tina's Wonderlands: Season Pass   2022-06-23
# 31874      18178   252050            Construction Machines 2014   2014-03-28
# 46903      18179   257930                          Race To Mars   2014-03-07
#
#        positive_ratio  user_reviews    sort_value
# 14398              88       7494460  2.087214e+06
# 13035              97        943413  6.956955e+05
# 15363              96        853733  5.675896e+05
# 47791              98        637341  5.207540e+05
# 47380              93        985819  4.771190e+05
# ...               ...           ...           ...
# 14292              10           439  4.390000e-08
# 37568              11           134  3.475615e-08
# 43990              10           164  1.640000e-08
# 31874               8           237  2.544768e-09
# 46903               6           225  1.360489e-10
#
# [18179 rows x 7 columns]

# %%
common_app_ids = pd.Series(list(set(reviews['app_id']).intersection(set(games['app_id']))))
print(common_app_ids)
# Out:
# 0         360450
# 1         688130
# 2          32770
# 3          65540
# 4         262150
#           ...
# 15075    1638390
# 15076      65530
# 15077    1966070
# 15078     753660
# 15079    1441790
# Length: 15080, dtype: int64

# %%
reviews = reviews[reviews['app_id'].isin(common_app_ids)]
games = games[games['app_id'].isin(common_app_ids)]

# %%
print(reviews)
# Out:
#            app_id  is_recommended   user_id
# 0          975370            True     51580
# 1          304390           False      2586
# 2         1085660            True    253880
# 3          703080            True    259432
# 4          526870            True     23869
# ...           ...             ...       ...
# 41154789   633230            True   1606890
# 41154790   758870           False   1786254
# 41154791   696170           False   6370324
# 41154792   696170            True   1044289
# 41154793  1089980            True  13971935
#
# [40550777 rows x 3 columns]

# %%
print(games)
# Out:
#        sort_rank   app_id                             title date_release  \
# 14398          1      730  Counter-Strike: Global Offensive   2012-08-21
# 13035          2   105600                          Terraria   2011-05-16
# 15363          3     4000                       Garry's Mod   2006-11-29
# 47791          4   431960                  Wallpaper Engine   2018-11-01
# 47380          5      440                   Team Fortress 2   2007-10-10
# ...          ...      ...                               ...          ...
# 33801      18169   656530               Pro Gamer Manager 2   2017-10-05
# 30768      18172  1563130                      SuperPower 3   2022-10-07
# 29539      18173   273770                   Game Tycoon 1.5   2014-02-11
# 37568      18176   913780                          NEW LIFE   2019-08-12
# 31874      18178   252050        Construction Machines 2014   2014-03-28
#
#        positive_ratio  user_reviews    sort_value
# 14398              88       7494460  2.087214e+06
# 13035              97        943413  6.956955e+05
# 15363              96        853733  5.675896e+05
# 47791              98        637341  5.207540e+05
# 47380              93        985819  4.771190e+05
# ...               ...           ...           ...
# 33801              13           145  1.998948e-07
# 30768              10           880  8.800000e-08
# 29539              11           317  8.222164e-08
# 37568              11           134  3.475615e-08
# 31874               8           237  2.544768e-09
#
# [15080 rows x 7 columns]

# %%
reviews = reviews.drop_duplicates()

# %%
reviews.to_csv("final_reviews.csv", index=False)
games.to_csv("final_games.csv", index=False)
